# %%
import pandas as pd
df = pd.read_csv("../Datasets/titanic.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
df[["Name", "Sex", "Ticket", "Cabin", "Embarked"]]
# Out:
#                                                   Name     Sex  \
# 0                              Braund, Mr. Owen Harris    male
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                               Heikkinen, Miss. Laina  female
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                             Allen, Mr. William Henry    male
# ..                                                 ...     ...
# 886                              Montvila, Rev. Juozas    male
# 887                       Graham, Miss. Margaret Edith  female
# 888           Johnston, Miss. Catherine Helen "Carrie"  female
# 889                              Behr, Mr. Karl Howell    male
# 890                                Dooley, Mr. Patrick    male
#
#                Ticket Cabin Embarked
# 0           A/5 21171   NaN        S
# 1            PC 17599   C85        C
# 2    STON/O2. 3101282   NaN        S
# 3              113803  C123        S
# ...

# %%
# 1 Describe function
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# 2 Extracting string object 
df.dtypes[df.dtypes == "object"].index
# Out:
# Index(['Name', 'Sex', 'Ticket', 'Cabin', 'Embarked'], dtype='object')

# %%
type(df.dtypes[df.dtypes == "object"])
# Out:
# pandas.core.series.Series

# %%
type([[df["Name"]]])
# Out:
# list

# %%
df[df.dtypes[df.dtypes == "object"].index].describe()
# Out:
#                            Name   Sex  Ticket Cabin Embarked
# count                       891   891     891   204      889
# unique                      891     2     681   147        3
# top     Braund, Mr. Owen Harris  male  347082    G6        S
# freq                          1   577       7     4      644

# %%
df[["Age", "Fare", "Survived"]]
# Out:
#       Age     Fare  Survived
# 0    22.0   7.2500         0
# 1    38.0  71.2833         1
# 2    26.0   7.9250         1
# 3    35.0  53.1000         1
# 4    35.0   8.0500         0
# ..    ...      ...       ...
# 886  27.0  13.0000         0
# 887  19.0  30.0000         1
# 888   NaN  23.4500         0
# 889  26.0  30.0000         1
# 890  32.0   7.7500         0
#
# [891 rows x 3 columns]

# %%
# 3 creating new colunm -> age + fare
df["Age + Fare"] = df["Age"] + df["Fare"]
df[["Age", "Fare", "Age + Fare"]]
# Out:
#       Age     Fare  Age + Fare
# 0    22.0   7.2500     29.2500
# 1    38.0  71.2833    109.2833
# 2    26.0   7.9250     33.9250
# 3    35.0  53.1000     88.1000
# 4    35.0   8.0500     43.0500
# ..    ...      ...         ...
# 886  27.0  13.0000     40.0000
# 887  19.0  30.0000     49.0000
# 888   NaN  23.4500         NaN
# 889  26.0  30.0000     56.0000
# 890  32.0   7.7500     39.7500
#
# [891 rows x 3 columns]

# %%
# 4 using categorical
pd.Categorical(df["Sex"])
# pd.Categorical(df["Age"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'male', 'female', 'female', 'male', 'male']
# Length: 891
# Categories (2, object): ['female', 'male']

# %%
# 5 Contidionals in pandas
df[df["Age"] > 70]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 96            97         0       1             Goldschmidt, Mr. George B
# 116          117         0       3                  Connors, Mr. Patrick
# 493          494         0       1               Artagaveytia, Mr. Ramon
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
# 851          852         0       3                   Svensson, Mr. Johan
#
#       Sex   Age  SibSp  Parch    Ticket     Fare Cabin Embarked  Age + Fare
# 96   male  71.0      0      0  PC 17754  34.6542    A5        C    105.6542
# 116  male  70.5      0      0    370369   7.7500   NaN        Q     78.2500
# 493  male  71.0      0      0  PC 17609  49.5042   NaN        C    120.5042
# 630  male  80.0      0      0     27042  30.0000   A23        S    110.0000
# 851  male  74.0      0      0    347060   7.7750   NaN        S     81.7750

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare  Age + Fare
# count  891.000000  891.000000  714.000000
# mean     0.381594   32.204208   64.393632
# std      0.806057   49.693429   56.206141
# min      0.000000    0.000000    8.936700
# 25%      0.000000    7.910400   33.500000
# 50%      0.000000   14.454200   46.625000
# 75%      0.000000   31.000000   73.822950
# ...

# %%
# 6 Average fare is 32.204208 find passenges paid more than this
len(df[df["Fare"] > 32.204208])
# Out:
# 211

# %%
# 7 select the name of persons paid no money

# %%
df[df["Fare"] == 0]
# len(df[df["Fare"] == 0])
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 179          180         0       3               Leonard, Mr. Lionel  male
# 263          264         0       1             Harrison, Mr. William  male
# 271          272         1       3      Tornquist, Mr. William Henry  male
# 277          278         0       2       Parkes, Mr. Francis "Frank"  male
# 302          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 413          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 466          467         0       2             Campbell, Mr. William  male
# 481          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 597          598         0       3               Johnson, Mr. Alfred  male
# 633          634         0       1     Parr, Mr. William Henry Marsh  male
# 674          675         0       2        Watson, Mr. Ennis Hastings  male
# ...

# %%
# 8 name of person who traveled free yet survived
df[(df["Fare"] == 0) & (df["Survived"] == 1)]
# Out:
#      PassengerId  Survived  Pclass                          Name   Sex   Age  \
# 271          272         1       3  Tornquist, Mr. William Henry  male  25.0
#
#      SibSp  Parch Ticket  Fare Cabin Embarked  Age + Fare
# 271      0      0   LINE   0.0   NaN        S        25.0

# %%
# 9 Female paid more than average fair
df[(df["Fare"] > 36) & (df["Sex"] == "female")]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 31            32         1       1
# 43            44         1       2
# 52            53         1       1
# ..           ...       ...     ...
# 853          854         1       1
# 856          857         1       1
# 863          864         0       3
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# 52            Harper, Mrs. Henry Sleeper (Myna Haxtun)  female  49.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %%
# 10 name of person paid max fare
df["Fare"] == max(df["Fare"])
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886    False
# 887    False
# 888    False
# 889    False
# 890    False
# Name: Fare, Length: 891, dtype: bool

# %%
df[df["Fare"] == max(df["Fare"])]["Name"]
# Out:
# 258                      Ward, Miss. Anna
# 679    Cardeza, Mr. Thomas Drake Martinez
# 737                Lesurer, Mr. Gustave J
# Name: Name, dtype: object

# %%
# 11 selecting first 2 rows
df[0:2]
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked  Age + Fare
# 0      0  A/5 21171   7.2500   NaN        S     29.2500
# 1      0   PC 17599  71.2833   C85        C    109.2833

# %%
# 12 select specific part of data as select survived sex age and fare of first 10
df[["Age", "Sex", "Survived", "Fare"]][0:6]
# Out:
#     Age     Sex  Survived     Fare
# 0  22.0    male         0   7.2500
# 1  38.0  female         1  71.2833
# 2  26.0  female         1   7.9250
# 3  35.0  female         1  53.1000
# 4  35.0    male         0   8.0500
# 5   NaN    male         0   8.4583

# %%
df.iloc[0:6, [9, 4, 5]]
# Out:
#       Fare     Sex   Age
# 0   7.2500    male  22.0
# 1  71.2833  female  38.0
# 2   7.9250  female  26.0
# 3  53.1000  female  35.0
# 4   8.0500    male  35.0
# 5   8.4583    male   NaN

# %% [markdown]
# ##### 13 Providing named indices (by default pandas give number indexed when we access the data)

# %%
s = df["Name"][0: 7]

# %%
l = ['name1', 'name2', 'name3', 'name4', 'name5', 'name6', 'name7']
named_index = pd.Series(list(s) ,index = l)

# %%
named_index
named_index["name2"]
# Out:
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'

# %%
named_index[1]
# Out:
# /tmp/ipykernel_19439/3827069140.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   named_index[1]
# 'Cumings, Mrs. John Bradley (Florence Briggs Thayer)'
