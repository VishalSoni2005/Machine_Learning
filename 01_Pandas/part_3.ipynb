# %%
import pandas as pd

df = pd.read_csv("../Datasets/titanic.csv")
# df.head()
original_df = df

# %% [markdown]
# ### Drop a Column

# %%
df.drop("PassengerId", axis = 1, inplace = True) # axis 1 is for column and 0 is for row

# %%
# df # in place is used to change it from original dataset

# %% [markdown]
# ## Drop a row

# %%
df.drop(0, inplace = True)

# %%
# df # oth index row deleted from data frame

# %% [markdown]
# ## 1 set name as index and then reset it

# %%
df.set_index("Name", inplace = True)

# %%
# df

# %%
df.reset_index(inplace = True)

# %% [markdown]
# ## 2 Filling every NaN values with David Gogins

# %%
# df[df.isna().any(axis=1)]

# %%
# df.columns[df.isna().any()]
# df.isna()

# %%
# df.fillna("David Gogins", inplace = True)
# df

# %% [markdown]
# ## 3 Grouping data

# %%
g = df.groupby("Survived")
g.first()
# Out:
#                                                        Name  Pclass     Sex  \
# Survived
# 0                                  Allen, Mr. William Henry       3    male
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...       1  female
#
#            Age  SibSp  Parch    Ticket     Fare Cabin Embarked
# Survived
# 0         35.0      0      0    373450   8.0500   E46        S
# 1         38.0      1      0  PC 17599  71.2833   C85        C

# %%
g.sum()
# Out:
#                                                        Name  Pclass  \
# Survived
# 0         Allen, Mr. William HenryMoran, Mr. JamesMcCart...    1387
# 1         Cumings, Mrs. John Bradley (Florence Briggs Th...     667
#
#                                                         Sex       Age  SibSp  \
# Survived
# 0         malemalemalemalemalemalefemalemalefemalemalefe...  12963.50    303
# 1         femalefemalefemalefemalefemalefemalefemalefema...   8219.67    162
#
#           Parch                                             Ticket  \
# Survived
# 0           181  37345033087717463349909A/5. 215134708235040638...
# 1           159  PC 17599STON/O2. 3101282113803347742237736PP 9...
#
#                 Fare                                              Cabin  \
# Survived
# 0         12135.4699  E46C23 C25 C27B30C83F G73E31A5D26C110B58 B60D2...
# 1         16551.2294  C85C123G6C103D56A6B78D33C52B28F33C23 C25 C27D1...
#
#                                                    Embarked
# Survived
# 0         SQSSSSSQSSSCSSCSCSSSSSCSQCSSSCCSCSSCSSSSSCSSSS...
# 1         CSSSCSSSSCSQSSQCQCCCQQCSSSSCSSSSSSQSSSCSSSQSCS...

# %%
g1 = df.groupby("Pclass")["Fare"]
g1.sum()
# Out:
# Pclass
# 1    18177.4125
# 2     3801.8417
# 3     6707.4451
# Name: Fare, dtype: float64

# %%
g1.max("Age")
# Out:
# Pclass
# 1    512.3292
# 2     73.5000
# 3     69.5500
# Name: Fare, dtype: float64

# %%
g1.sum()
g1.mean().tolist()
# Out:
# [84.1546875, 20.662183152173913, 13.688663469387755]

# %% [markdown]
# ## make a col of fare in rs

# %%
# original_df
# data = original_df[["Pclass", "Fare"]]

# data["Fare_INR"] = df['Fare'].apply(lambda x : x * 80)
# data["Fare_INR"].groupby("Pclass").mean()

# Step 1: Create a clean working copy
data = original_df[["Pclass", "Fare"]].copy()

# Step 2: Convert Fare to INR
data["Fare_INR"] = data['Fare'].apply(lambda x: x * 80)

# Step 3: Group by Pclass and take average INR fare
result = data.groupby("Pclass")[["Fare", "Fare_INR"]]

result.first()
# Out:
#            Fare  Fare_INR
# Pclass
# 1       71.2833  5702.664
# 2       30.0708  2405.664
# 3        7.2500   580.000

# %% [markdown]
# ## Custome Function

# %%
original_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %%
agg_df = original_df[["Pclass", "Sex", "Fare", "Age"]]
agg_df
# Out:
#      Pclass     Sex     Fare   Age
# 0         3    male   7.2500  22.0
# 1         1  female  71.2833  38.0
# 2         3  female   7.9250  26.0
# 3         1  female  53.1000  35.0
# 4         3    male   8.0500  35.0
# ..      ...     ...      ...   ...
# 886       2    male  13.0000  27.0
# 887       1  female  30.0000  19.0
# 888       3  female  23.4500   NaN
# 889       1    male  30.0000  26.0
# 890       3    male   7.7500  32.0
#
# [891 rows x 4 columns]

# %%
def Aukad(x):
    if(x <= 10) : 
        return "Garib"
    elif(x > 10 and x < 50) :
        return "Middle Class"
    else :
        return "Reptilian"

agg_df["Human_Status"] = agg_df["Fare"].apply(Aukad)
agg_df
# Out:
# /tmp/ipykernel_13110/3206518261.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   agg_df["Human_Status"] = agg_df["Fare"].apply(Aukad)
#      Pclass     Sex     Fare   Age  Human_Status
# 0         3    male   7.2500  22.0         Garib
# 1         1  female  71.2833  38.0     Reptilian
# 2         3  female   7.9250  26.0         Garib
# 3         1  female  53.1000  35.0     Reptilian
# 4         3    male   8.0500  35.0         Garib
# ..      ...     ...      ...   ...           ...
# 886       2    male  13.0000  27.0  Middle Class
# 887       1  female  30.0000  19.0  Middle Class
# 888       3  female  23.4500   NaN  Middle Class
# 889       1    male  30.0000  26.0  Middle Class
# 890       3    male   7.7500  32.0         Garib
#
# [891 rows x 5 columns]
