# %%
import pandas as pd

# Load CSV
df = pd.read_csv('Heart.csv')

df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
# a) Find Shape of Data
print("Shape of dataset:", df.shape)
# Out:
# Shape of dataset: (303, 15)

# %%
df.describe()
# Out:
#        Unnamed: 0         Age         Sex      RestBP        Chol         Fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean   152.000000   54.438944    0.679868  131.689769  246.693069    0.148515
# std     87.612784    9.038662    0.467299   17.599748   51.776918    0.356198
# min      1.000000   29.000000    0.000000   94.000000  126.000000    0.000000
# 25%     76.500000   48.000000    0.000000  120.000000  211.000000    0.000000
# 50%    152.000000   56.000000    1.000000  130.000000  241.000000    0.000000
# 75%    227.500000   61.000000    1.000000  140.000000  275.000000    0.000000
# max    303.000000   77.000000    1.000000  200.000000  564.000000    1.000000
#
#           RestECG       MaxHR       ExAng     Oldpeak       Slope          Ca
# count  303.000000  303.000000  303.000000  303.000000  303.000000  299.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660    0.672241
# ...

# %%
# b> find null value
print("Missing values:\n", df.isnull().sum())
# Out:
# Missing values:
#  Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
df.isnull()
# Out:
#      Unnamed: 0    Age    Sex  ChestPain  RestBP   Chol    Fbs  RestECG  \
# 0         False  False  False      False   False  False  False    False
# 1         False  False  False      False   False  False  False    False
# 2         False  False  False      False   False  False  False    False
# 3         False  False  False      False   False  False  False    False
# 4         False  False  False      False   False  False  False    False
# ..          ...    ...    ...        ...     ...    ...    ...      ...
# 298       False  False  False      False   False  False  False    False
# 299       False  False  False      False   False  False  False    False
# 300       False  False  False      False   False  False  False    False
# 301       False  False  False      False   False  False  False    False
# 302       False  False  False      False   False  False  False    False
#
#      MaxHR  ExAng  Oldpeak  Slope     Ca   Thal    AHD
# ...

# %%
# finding data type of each row

# %%
print("Data Type of Each Row is : \n", df.dtypes)
# Out:
# Data Type of Each Row is :
#  Unnamed: 0      int64
# Age             int64
# Sex             int64
# ChestPain      object
# RestBP          int64
# Chol            int64
# Fbs             int64
# RestECG         int64
# MaxHR           int64
# ExAng           int64
# Oldpeak       float64
# Slope           int64
# Ca            float64
# Thal           object
# AHD            object
# dtype: object

# %%
df
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# ...

# %%
# d> finding number of zeros
print("Number of Zeros in Each colums : \n", (df == 0).sum())
# Out:
# Number of Zeros in Each colums :
#  Unnamed: 0      0
# Age             0
# Sex            97
# ChestPain       0
# RestBP          0
# Chol            0
# Fbs           258
# RestECG       151
# MaxHR           0
# ExAng         204
# Oldpeak        99
# Slope           0
# Ca            176
# Thal            0
# AHD             0
# dtype: int64

# %%
#  e) Find Mean Age of Patients

print("Mean age of petient : ", df["Age"].mean())
print("Mean sex of petient : ", df["Sex"].mean())
print("Mean Fbs of petient : ", df["Fbs"].mean())
print("Mean MaxHR of petient : ", df["MaxHR"].mean())
# Out:
# Mean age of petient :  54.43894389438944
# Mean sex of petient :  0.6798679867986799
# Mean Fbs of petient :  0.1485148514851485
# Mean MaxHR of petient :  149.6072607260726

# %% [markdown]
# # f) Splitting the dataset randomly into 75% training and 25% testing:

# %%
from sklearn.model_selection import train_test_split

selected_col = df[['Age', 'Sex', 'ChestPain', 'RestBP', 'Chol']]
# print(selected_col)

train_data, test_data = train_test_split(selected_col, test_size=0.25, random_state=42)
print("Training data shape:", train_data.shape)
print("Testing data shape:", test_data.shape)

train_data
test_data
# Out:
# Training data shape: (227, 5)
# Testing data shape: (76, 5)
#      Age  Sex     ChestPain  RestBP  Chol
# 179   53    1    nonanginal     130   246
# 228   54    1  asymptomatic     110   206
# 111   56    1  asymptomatic     125   249
# 246   58    1  asymptomatic     100   234
# 60    51    0  asymptomatic     130   305
# ..   ...  ...           ...     ...   ...
# 22    58    1    nontypical     120   284
# 258   70    1    nontypical     156   245
# 56    50    1    nonanginal     140   233
# 242   49    0  asymptomatic     130   269
# 114   62    0    nonanginal     130   263
#
# [76 rows x 5 columns]
